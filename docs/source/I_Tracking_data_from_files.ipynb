# %% [markdown]
# # Example I: Tracking data stored in files
#
# In this example notebook we are going to track rain-rates that are estimated from radar based reflectivities. The rain-rates is an example dataset from the CPOL radar archive that used to operate north of Darwin, Australia. This example dataset has been provided by Valentin Louf from the Australian Bureau of Meteorology.
#
# A more detailed example of the application of the tracking algorithm can be found in [doi: 10.1002/qj.4360](https://rmets.onlinelibrary.wiley.com/doi/abs/10.1002/qj.4360)
#
# Before we get started we import all modules that are needed to apply the tracking

# %%
from IPython.display import HTML
from tintx import RunDirectory, config
import xarray as xr
import pandas as pd
from pathlib import Path
import os
# %matplotlib inline

# %%
os.environ["DATA_FILES"] = "_static/data"

# %% [markdown]
# In this example we want to apply the tracking algorithm only for a limited time period. Such time periods can be passed as string or `datetime` object. If defined as a string make sure they follow the [ISO 8061](https://en.wikipedia.org/wiki/ISO_8601) convention.

# %%
first = '2006-11-16 03:00' #Start-date
last = '2006-11-16 11:00' #End-date
data_files = Path(os.environ["DATA_FILES"])

# %% [markdown]
# To apply the tracking we create an instance of the `RunDirectory` class. Normally we would have to create this instance with a `xarray.DataArray`. The `from_files` method is a convenience method that allows us to create this instance without opening a dataset. The method will open the data files and create an object. We will have to provide a filename or a list of files, the name of the variable and if not according to cf conventions the names of the *longitude*, *latitude* and *time* dimensions:

# %%
RD = RunDirectory.from_files( data_files / "CPOL_radar.nc", "radar_estimated_rain_rate",
                             start=first, end=last, use_cftime=True, x_coord="longitude", y_coord="latitude")

# %% [markdown]
# Additional keyword arguments can be added to the `xarray.open_mfdataset` method. In this example we used the `use_cftime` keyword to convert the time variable to cftime vectors.

# %% [markdown]
# ### The tuning parameters
# To apply the actual tracking algorithm we can use the `get_tracks` method. The algorithm can be tuned by passing the values for the tuning parameters. See also the [tuning parameter section](api.html#tracking-parameter-guide) of the docs.

# %%
print(config.__doc__)
# Out:
# Tracking tuning parameters
# --------------------------
#
# The following parameter can be set to tune the cell tracking algorithm
#
# * field_thresh: units of 'field' attribute, default: 32
#     The threshold used for object detection. Detected objects are connected
#     pixels above this threshold.
# * iso_thresh: units of 'field' attribute, default: 4
#     Used in isolated cell classification. Isolated cells must not be connected
#     to any other cell by contiguous pixels above this threshold.
# * iso_smooth: pixels, default: 4
#     Gaussian smoothing parameter in peak detection preprocessing. See
#     single_max in tint.objects.
# * min_size: square kilometers, default: 8
#     The minimum size threshold in pixels for an object to be detected.
# * search_margin: meters, default: 250
#     The radius of the search box around the predicted object center.
# * flow_margin: meters, default: 750
#     The margin size around the object extent on which to perform phase
#     correlation.
# * max_disparity: float, default: 999
#     Maximum allowable disparity value. Larger disparity values are sent to a
#     large number.
# * max_flow_mag: meters per second, default: 50
#     Maximum allowable global shift magnitude. See get_global_shift in
#     tint.phase_correlation.
# * max_shift_disp: meters per second, default: 15
#     Maximum magnitude of difference in meters per second for two shifts to be
#     considered in agreement. See correct_shift in tint.matching.
# * gs_alt: meters, default: 1500
#     Altitude in meters at which to perform phase correlation for global shift
#     calculation. See correct_shift in tint.matching.
#
#
# Setting and getting the tuning parameters
# -----------------------------------------
# The parameters can the set using the :py:class:`tintx.config.set` class.
# Getting the values of the currently set parameters can be done by the
# :py:func:`tintx.config.get` method.

# %% [markdown]
# Apply the tracking with a rain-rate threshold of 0.1 and a minimum size of 4. The return value of the function will be the total number of individual storms identified by the algorithm.

# %%
num_cells = RD.get_tracks(field_thresh=0.1, min_size=4)
print(f"Number of storm cells found: {num_cells}")
# Out:
# Tracking:   0%|          | 0/48 [00:00<?, ?it/s]
# Number of storm cells found: 125

# %%
RD

# %% [markdown]
# ### Accessing the track data
# The actual tracking data is stored in a multi-index [pandas.DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.MultiIndex.html) and can be accessed via the `tracks` property:

# %%
RD.tracks.plot(aspect=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# After each tracking the `RunDirectory` class creates a so called hash of the resulting `DataFrame` and saves the
# tuning parameters for this specific tracking. The next time you call the tracking method the previous tuning parameters are noted and set automatically. This means that in the above example the `filed_thresh` and `min_size` parameters are automatically set for the next tracking.

# %%
gdf.geometry.plot(aspect=1, cmap="turbo")
gdf.crs.to_wkt()

# %%
crs1.to_wkt()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as crs
# source coordinates are in AEQD
map_trans = crs.AzimuthalEquidistant(
    central_latitude=RD.data.latitude.mean().values.item(), central_longitude=RD.data.longitude.mean().values.item()
)

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(121, projection=crs.PlateCarree())

# copy tracks and import shapely POLYGON into GeoDataFrame
gdf = RD.tracks.copy()

# plot everything
gdf.plot(ax=ax, cmap="viridis", facecolor="None", transform=map_trans, aspect=1)
ax.coastlines(resolution="10m")

# plot single track
ax = fig.add_subplot(122, projection=crs.PlateCarree())
gdf["geometry"][:, "22"].plot(ax=ax, cmap="turbo", facecolor="None", transform=map_trans, aspect=1)
ax.coastlines(resolution="10m")

# %% [markdown]
# ## Displaying the results
# Let's do some visualisation and create an animation of the tracks. This can be done by calling the `animate` method.
#
# **Note:** To convert possible UTC time strings to local time we can give a time shift (`dt`) in hours. The plot styling can be fine tuned by the `plot_style` key word

# %%
anim = RD.animate(dt=9.5, fps=2, vmin=0.01, plot_style=dict(resolution="10m", title="Rain-rate"))

# %% [markdown]
# The return value is a [matplotlib FuncAnimation Object](https://matplotlib.org/stable/api/_as_gen/matplotlib.animation.FuncAnimation.html). The animation can be save or displayed in a notebook:

# %%
HTML(anim.to_html5_video())

# %% [markdown]
# It is also possible to save the animation to a file:

# %% [markdown]
# ```python
# anim.save("cpol_tracking.gif", fps=3)
# ```

# %% [markdown]
# The traces of the tracks can also be plotted using the `plot_trajectories` method:

# %%
ax = RD.plot_trajectories(mintrace=4, plot_style=dict(lw=2))

# %%
RD.crs

# %% [markdown]
# ## Saving the tracks for later analysis:
# For a later analysis the results can be saved using the `save_tracks` method. This will save the tracks `DataFrame` to a hdf5 table format. hdf5 is the format of choice as it can save additional meta data like the tracking parameters.

# %%
RD.save_tracks("/tmp/tint_tracks.h5")

# %%
# !ncdump -h /tmp/tint_tracks.h5
# Out:
# netcdf tint_tracks {
#
# // global attributes:
# 		:TITLE = "" ;
# 		:VERSION = "1.0" ;
# 		:PYTABLES_FORMAT_VERSION = "2.1" ;
#
# group: dims {
#   dimensions:
#   	phony_dim_0 = 3 ;
#   	phony_dim_1 = 117 ;
#   	phony_dim_2 = 2 ;
#   	phony_dim_3 = 1 ;
#   variables:
#   	string axis0(phony_dim_0) ;
#   		axis0:VERSION = "2.4" ;
#   		axis0:TITLE = "" ;
#   		axis0:FLAVOR = "numpy" ;
#   		axis0:kind = "string" ;
#   		axis0:name = "N." ;
#   	int64 axis1(phony_dim_1) ;
#   		axis1:VERSION = "2.4" ;
#   		axis1:TITLE = "" ;
#   		axis1:FLAVOR = "numpy" ;
#   		axis1:kind = "integer" ;
#   		axis1:name = "N." ;
#   	char block0_items(phony_dim_2) ;
#   		block0_items:VERSION = "2.4" ;
#   		block0_items:TITLE = "" ;
#   		block0_items:FLAVOR = "numpy" ;
#   		block0_items:kind = "string" ;
#   		block0_items:name = "N." ;
#   	int block0_values(phony_dim_1, phony_dim_2) ;
#   		block0_values:VERSION = "2.4" ;
#   		block0_values:TITLE = "" ;
#   		block0_values:FLAVOR = "numpy" ;
#   	string block1_items(phony_dim_3) ;
#   		block1_items:VERSION = "2.4" ;
#   		block1_items:TITLE = "" ;
#   		block1_items:FLAVOR = "numpy" ;
#   		block1_items:kind = "string" ;
#   		block1_items:name = "N." ;
#   	double block1_values(phony_dim_1, phony_dim_3) ;
#   		block1_values:VERSION = "2.4" ;
#   		block1_values:TITLE = "" ;
#   		block1_values:FLAVOR = "numpy" ;
#
#   // group attributes:
#   		:TITLE = "" ;
#   		:VERSION = "1.0" ;
#   		:pandas_type = "frame" ;
#   		:pandas_version = "0.15.2" ;
#   		:encoding = "UTF-8" ;
#   		:errors = "strict" ;
#   		:ndim = 2LL ;
#   		:axis0_variety = "regular" ;
#   		:axis1_variety = "regular" ;
#   		:nblocks = 2LL ;
#   		:block0_items_variety = "regular" ;
#   		:block1_items_variety = "regular" ;
#   		:dim_attrs = "(dp0\nVtime\np1\n(dp2\nVcalendar\np3\nVstandard\np4\nsVunits\np5\nVseconds since 1970-01-01T00:00:00\np6\nssVx\np7\n(dp8\nVunits\np9\nVmeters\np10\nssVy\np11\n(dp12\nVunits\np13\nVmeters\np14\nss." ;
#   		:var_attrs = "(dp0\nVunits\np1\nVmm h-1\np2\nsVlong_name\np3\nVBlended Rainfall Rate\np4\nsVstandard_name\np5\nVRainfall Rate\np6\nsVdescription\np7\nVRainfall rate algorithm based on Thompson et al. 2016.\np8\nsVtime_coord\np9\nVtime\np10\nsVshort_name\np11\nVradar_estimated_rain_rate\np12\ns." ;
#   		:dims = "(Vtime\np0\nVx\np1\nVy\np2\ntp3\n." ;
#   } // group dims
#
# group: tintx_tracks {
#   dimensions:
#   	phony_dim_4 = 10 ;
#   	phony_dim_5 = 299 ;
#   	phony_dim_6 = 48 ;
#   	phony_dim_7 = 125 ;
#   	phony_dim_8 = 1 ;
#   	phony_dim_9 = 6 ;
#   	phony_dim_10 = 2 ;
#   variables:
#   	string axis0(phony_dim_4) ;
#   		axis0:VERSION = "2.4" ;
#   		axis0:TITLE = "" ;
#   		axis0:FLAVOR = "numpy" ;
#   		axis0:kind = "string" ;
#   		axis0:name = "N." ;
#   	byte axis1_label0(phony_dim_5) ;
#   		axis1_label0:VERSION = "2.4" ;
#   		axis1_label0:TITLE = "" ;
#   		axis1_label0:FLAVOR = "numpy" ;
#   	byte axis1_label1(phony_dim_5) ;
#   		axis1_label1:VERSION = "2.4" ;
#   		axis1_label1:TITLE = "" ;
#   		axis1_label1:FLAVOR = "numpy" ;
#   	int64 axis1_level0(phony_dim_6) ;
#   		axis1_level0:VERSION = "2.4" ;
#   		axis1_level0:TITLE = "" ;
#   		axis1_level0:FLAVOR = "numpy" ;
#   		axis1_level0:kind = "integer" ;
#   		axis1_level0:name = "scan" ;
#   		axis1_level0:axis1_namescan = "scan" ;
#   	string axis1_level1(phony_dim_7) ;
#   		axis1_level1:VERSION = "2.4" ;
#   		axis1_level1:TITLE = "" ;
#   		axis1_level1:FLAVOR = "numpy" ;
#   		axis1_level1:kind = "string" ;
#   		axis1_level1:name = "uid" ;
#   		axis1_level1:axis1_nameuid = "uid" ;
#   	string block0_items(phony_dim_8) ;
#   		block0_items:VERSION = "2.4" ;
#   		block0_items:TITLE = "" ;
#   		block0_items:FLAVOR = "numpy" ;
#   		block0_items:kind = "string" ;
#   		block0_items:name = "N." ;
#   	string block1_items(phony_dim_9) ;
#   		block1_items:VERSION = "2.4" ;
#   		block1_items:TITLE = "" ;
#   		block1_items:FLAVOR = "numpy" ;
#   		block1_items:kind = "string" ;
#   		block1_items:name = "N." ;
#   	double block1_values(phony_dim_5, phony_dim_9) ;
#   		block1_values:VERSION = "2.4" ;
#   		block1_values:TITLE = "" ;
#   		block1_values:FLAVOR = "numpy" ;
#   	string block2_items(phony_dim_8) ;
#   		block2_items:VERSION = "2.4" ;
#   		block2_items:TITLE = "" ;
#   		block2_items:FLAVOR = "numpy" ;
#   		block2_items:kind = "string" ;
#   		block2_items:name = "N." ;
#   	int64 block2_values(phony_dim_5, phony_dim_8) ;
#   		block2_values:VERSION = "2.4" ;
#   		block2_values:TITLE = "" ;
#   		block2_values:FLAVOR = "numpy" ;
#   	string block3_items(phony_dim_10) ;
#   		block3_items:VERSION = "2.4" ;
#   		block3_items:TITLE = "" ;
#   		block3_items:FLAVOR = "numpy" ;
#   		block3_items:kind = "string" ;
#   		block3_items:name = "N." ;
#
#   // group attributes:
#   		:TITLE = "" ;
#   		:VERSION = "1.0" ;
#   		:pandas_type = "frame" ;
#   		:pandas_version = "0.15.2" ;
#   		:encoding = "UTF-8" ;
#   		:errors = "strict" ;
#   		:ndim = 2LL ;
#   		:axis0_variety = "regular" ;
#   		:axis1_variety = "multi" ;
#   		:axis1_nlevels = 2LL ;
#   		:nblocks = 4LL ;
#   		:block0_items_variety = "regular" ;
#   		:block1_items_variety = "regular" ;
#   		:block2_items_variety = "regular" ;
#   		:block3_items_variety = "regular" ;
#   		:track_meta = "(dp0\nVx_coord\np1\nVlongitude\np2\nsVy_coord\np3\nVlatitude\np4\nsVtime_coord\np5\nVtime\np6\nsVvar_name\np7\nVradar_estimated_rain_rate\np8\nsVstart\np9\nV2006-11-16 03:00:00\np10\nsVend\np11\nV2006-11-16 11:00:00\np12\nsVfiles\np13\nV_static/data/CPOL_radar.nc\np14\nsVcrs\np15\nVGEOGCRS[\"WGS 84\",ENSEMBLE[\"World Geodetic System 1984 ensemble\",MEMBER[\"World Geodetic System 1984 (Transit)\"],MEMBER[\"World Geodetic System 1984 (G730)\"],MEMBER[\"World Geodetic System 1984 (G873)\"],MEMBER[\"World Geodetic System 1984 (G1150)\"],MEMBER[\"World Geodetic System 1984 (G1674)\"],MEMBER[\"World Geodetic System 1984 (G1762)\"],MEMBER[\"World Geodetic System 1984 (G2139)\"],ELLIPSOID[\"WGS 84\",6378137,298.257223563,LENGTHUNIT[\"metre\",1]],ENSEMBLEACCURACY[2.0]],PRIMEM[\"Greenwich\",0,ANGLEUNIT[\"degree\",0.0174532925199433]],CS[ellipsoidal,2],AXIS[\"geodetic latitude (Lat)\",north,ORDER[1],ANGLEUNIT[\"degree\",0.0174532925199433]],AXIS[\"geodetic longitude (Lon)\",east,ORDER[2],ANGLEUNIT[\"degree\",0.0174532925199433]],USAGE[SCOPE[\"Horizontal component of 3D system.\"],AREA[\"World.\"],BBOX[-90,-180,90,180]],ID[\"EPSG\",4326]]\np16\ns." ;
#   		:tracking_parameters = "(dp0\nVISO_THRESH\np1\nF4.0\nsVFIELD_THRESH\np2\nF0.1\nsVISO_SMOOTH\np3\nF4.0\nsVMIN_SIZE\np4\nF4.0\nsVSEARCH_MARGIN\np5\nF250.0\nsVFLOW_MARGIN\np6\nF750.0\nsVMAX_DISPARITY\np7\nF999.0\nsVMAX_FLOW_MAG\np8\nF50.0\nsVMAX_SHIFT_DISP\np9\nF15.0\nsVGS_ALT\np10\nF1500.0\ns." ;
#   } // group tintx_tracks
#
# group: x_coord {
#   dimensions:
#   	phony_dim_11 = 117 ;
#   	phony_dim_12 = 117 ;
#   variables:
#   	int64 axis0(phony_dim_11) ;
#   		axis0:VERSION = "2.4" ;
#   		axis0:TITLE = "" ;
#   		axis0:FLAVOR = "numpy" ;
#   		axis0:kind = "integer" ;
#   		axis0:name = "N." ;
#   	int64 axis1(phony_dim_11) ;
#   		axis1:VERSION = "2.4" ;
#   		axis1:TITLE = "" ;
#   		axis1:FLAVOR = "numpy" ;
#   		axis1:kind = "integer" ;
#   		axis1:name = "N." ;
#   	int64 block0_items(phony_dim_11) ;
#   		block0_items:VERSION = "2.4" ;
#   		block0_items:TITLE = "" ;
#   		block0_items:FLAVOR = "numpy" ;
#   		block0_items:kind = "integer" ;
#   		block0_items:name = "N." ;
#   	double block0_values(phony_dim_11, phony_dim_12) ;
#   		block0_values:VERSION = "2.4" ;
#   		block0_values:TITLE = "" ;
#   		block0_values:FLAVOR = "numpy" ;
#
#   // group attributes:
#   		:TITLE = "" ;
#   		:VERSION = "1.0" ;
#   		:pandas_type = "frame" ;
#   		:pandas_version = "0.15.2" ;
#   		:encoding = "UTF-8" ;
#   		:errors = "strict" ;
#   		:ndim = 2LL ;
#   		:axis0_variety = "regular" ;
#   		:axis1_variety = "regular" ;
#   		:nblocks = 1LL ;
#   		:block0_items_variety = "regular" ;
#   		:attrs = "(dp0\nVunits\np1\nVdegrees West\np2\nsVshort_name\np3\nVlongitude\np4\nsVdims\np5\n(Vx\np6\nVy\np7\ntp8\ns." ;
#   } // group x_coord
#
# group: y_coord {
#   dimensions:
#   	phony_dim_13 = 117 ;
#   	phony_dim_14 = 117 ;
#   variables:
#   	int64 axis0(phony_dim_13) ;
#   		axis0:VERSION = "2.4" ;
#   		axis0:TITLE = "" ;
#   		axis0:FLAVOR = "numpy" ;
#   		axis0:kind = "integer" ;
#   		axis0:name = "N." ;
#   	int64 axis1(phony_dim_13) ;
#   		axis1:VERSION = "2.4" ;
#   		axis1:TITLE = "" ;
#   		axis1:FLAVOR = "numpy" ;
#   		axis1:kind = "integer" ;
#   		axis1:name = "N." ;
#   	int64 block0_items(phony_dim_13) ;
#   		block0_items:VERSION = "2.4" ;
#   		block0_items:TITLE = "" ;
#   		block0_items:FLAVOR = "numpy" ;
#   		block0_items:kind = "integer" ;
#   		block0_items:name = "N." ;
#   	double block0_values(phony_dim_13, phony_dim_14) ;
#   		block0_values:VERSION = "2.4" ;
#   		block0_values:TITLE = "" ;
#   		block0_values:FLAVOR = "numpy" ;
#
#   // group attributes:
#   		:TITLE = "" ;
#   		:VERSION = "1.0" ;
#   		:pandas_type = "frame" ;
#   		:pandas_version = "0.15.2" ;
#   		:encoding = "UTF-8" ;
#   		:errors = "strict" ;
#   		:ndim = 2LL ;
#   		:axis0_variety = "regular" ;
#   		:axis1_variety = "regular" ;
#   		:nblocks = 1LL ;
#   		:block0_items_variety = "regular" ;
#   		:attrs = "(dp0\nVunits\np1\nVdegrees North\np2\nsVshort_name\np3\nVlatitude\np4\nsVdims\np5\n(Vx\np6\nVy\np7\ntp8\ns." ;
#   } // group y_coord
# }

# %% [markdown]
# ## Loading the tracked files
#
# If you have saved the tracked object with the `save_tracks` method you can create an instance of the `RunDirectory` object using the `from_dataframe` method. This method will load the tracks `DataFrame` and also try to re-open the data files that were used to track the object.

# %%
RD = RunDirectory.from_dataframe("/tmp/tint_tracks.h5")
RD.data
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 49, x: 117, y: 117)
# Coordinates:
#   * time                       (time) datetime64[ns] 2006-11-16T03:00:00 ... ...
#   * x                          (x) int32 -145000 -142500 ... 142500 145000
#   * y                          (y) int32 -145000 -142500 ... 142500 145000
# Data variables:
#     radar_estimated_rain_rate  (time, x, y) float64 dask.array<chunksize=(49, 117, 117), meta=np.ndarray>
#     latitude                   (x, y) float64 dask.array<chunksize=(117, 117), meta=np.ndarray>
#     longitude                  (x, y) float64 dask.array<chunksize=(117, 117), meta=np.ndarray>
#     isfile                     (time) int32 dask.array<chunksize=(49,), meta=np.ndarray>
# Attributes: (12/25)
#     Conventions:         CF/Radial instrument_parameters
#     version:             2017-10
#     title:               CPOL product level 2
#     institution:         Australia Bureau of Meteorology
#     references:          If you use this dataset, please cite: 'An integrated...
#     source:              UF raw files
#     ...                  ...
#     state:               NT
#     history:             October 2017 recalibration: May 2017 recalibration
#     volume_number:       0
#     platform_type:       fixed
#     instrument_type:     radar
#     primary_axis:        axis_z

# %%
RD.tracks
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 RD.tracks
#
# File ~/miniconda3/envs/wradlib_310/lib/python3.10/site-packages/tintx/reader.py:264, in RunDirectory.tracks(self)
#     261 """Pandas ``DataFrame`` representation of the tracked cells."""
#     262 #tracks = self._tracks.copy()
#     263 #tracks["geometry"] = [geometry.shape(geom) for geom in tracks["geometry"]]
# --> 264 return gpd.GeoDataFrame(self._tracks.copy(), crs=self.crs)
#
# File ~/miniconda3/envs/wradlib_310/lib/python3.10/site-packages/geopandas/geodataframe.py:191, in GeoDataFrame.__init__(self, data, geometry, crs, *args, **kwargs)
#     188     self.set_geometry(geometry, inplace=True, crs=crs)
#     190 if geometry is None and crs:
# --> 191     raise ValueError(
#     192         "Assigning CRS to a GeoDataFrame without a geometry column is not "
#     193         "supported. Supply geometry using the 'geometry=' keyword argument, "
#     194         "or by providing a DataFrame with column name 'geometry'",
#     195     )
#
# ValueError: Assigning CRS to a GeoDataFrame without a geometry column is not supported. Supply geometry using the 'geometry=' keyword argument, or by providing a DataFrame with column name 'geometry'

# %% [markdown]
# ## Obtaining tuning parameters from tracked objects

# %% [markdown]
# Sometimes it might be useful to retrieve the tuning parameters that resulted in certain object tracks. This is especially important when using the `from_dataframe` method. As previously mentioned the `RunDirectory` class keeps track of all tuning parameters that resulted in object tracks. To retrieve such tuning parameters you can use the `get_parameters` method. By default the method will look for latest track objects.

# %%
RD.get_parameters()

# %% [markdown]
# This concludes the first tutorial, in [the next one](II_Tracking_already_loaded_datasets.html) we will explore the application of the tracking algorithm to data has already been loaded.
